# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %%
n_rows = 365 * 24 
n_cols = 2         
cols = ['col1', 'col2'] 

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)

df.index = pd.date_range(start='2023-01-01', periods=n_rows, freq='h')

df.head()
# Out:
#                      col1  col2
# 2023-01-01 00:00:00     8     3
# 2023-01-01 01:00:00    10     6
# 2023-01-01 02:00:00    18    16
# 2023-01-01 03:00:00     1     9
# 2023-01-01 04:00:00     6     7

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_10812\1008014569.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample('M')['col1'].sum().to_frame()
#             col1
# 2023-01-31  7501
# 2023-02-28  6787
# 2023-03-31  7442
# 2023-04-30  7474
# 2023-05-31  7369
# 2023-06-30  7300
# 2023-07-31  7420
# 2023-08-31  7285
# 2023-09-30  7417
# 2023-10-31  7270
# 2023-11-30  7329
# 2023-12-31  7381

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2023-01-01   220
# 2023-01-02   275
# 2023-01-03   231
# 2023-01-04   228
# 2023-01-05   259
# ...          ...
# 2023-12-27   249
# 2023-12-28   226
# 2023-12-29   186
# 2023-12-30   258
# 2023-12-31   255
#
# [365 rows x 1 columns]
