# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %%
pd.DataFrame({'col1':[1, 2, 3, 4], 
              'col2':[5, 6, 7, 8]})
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %%
n_rows = 5
n_cols = 3

arr = np.random.randint(1, 20, size=(n_rows, n_cols))
arr
# Out:
# array([[ 9, 10,  8],
#        [15, 11, 11],
#        [10, 14, 19],
#        [ 2, 17, 19],
#        [10, 19, 12]], dtype=int32)

# %%
pd.DataFrame(arr, columns=tuple('ABC'))
# Out:
#     A   B   C
# 0   9  10   8
# 1  15  11  11
# 2  10  14  19
# 3   2  17  19
# 4  10  19  12

# %%
n_rows = 30 
n_cols = 4 
columns = list('ABCD')

data = np.random.randn(n_rows, n_cols)

df = pd.DataFrame(data, columns=columns)

print(df.head())
# Out:
#           A         B         C         D
# 0 -1.088101 -1.312180  0.390565 -0.410327
# 1 -0.743994  0.989697 -0.292835 -0.378428
# 2  0.657175 -0.094980  0.636180  1.296553
# 3  0.399071  0.289570  0.620446  1.407820
# 4  0.396943  0.965278 -2.018053 -0.828029

# %%
n_rows = 5 

data = {
    'A': np.random.randn(n_rows),                 
    'B': np.arange(1, n_rows + 1),                
    'C': pd.date_range('2024-01-01', periods=n_rows), 
    'D': ['foo', 'bar', 'baz', 'qux', 'quux']    
}

df = pd.DataFrame(data)

print(df.head())
# Out:
#           A  B          C     D
# 0 -0.017263  1 2024-01-01   foo
# 1  0.058151  2 2024-01-02   bar
# 2  1.592491  3 2024-01-03   baz
# 3 -0.443582  4 2024-01-04   qux
# 4 -0.052325  5 2024-01-05  quux

# %%
n_rows = 30  
n_cols = 4   
columns = list('ABCD')  

time_index = pd.date_range(start='2024-01-01', periods=n_rows, freq='D')  

df = pd.DataFrame(np.random.randn(n_rows, n_cols), index=time_index, columns=columns)

print(df.head())
# Out:
#                    A         B         C         D
# 2024-01-01  0.487444  0.462943 -1.078537 -0.261108
# 2024-01-02 -0.722360  0.162439 -0.430729  0.810439
# 2024-01-03  0.546814  0.501595  0.765714 -0.381570
# 2024-01-04  1.403686  1.838198 -0.555910  1.717403
# 2024-01-05 -0.799440 -0.004847 -0.376914  0.564010

# %%
n_rows = 5
n_cols = 4

data = np.random.randn(n_rows, n_cols)

df = pd.DataFrame(data, columns=list('ABCD'))

df.iloc[0, 1] = np.nan
df.iloc[2, 3] = np.nan
df.iloc[4, 0] = np.nan

print(df.head())
# Out:
#           A         B         C         D
# 0 -0.921369       NaN -0.748410 -0.707714
# 1 -1.986038  0.072099 -0.029908  1.367606
# 2 -0.683866  0.531750  0.953003       NaN
# 3  0.130375  1.088638  0.042922  0.373236
# 4       NaN -0.715086  0.121271  1.791043
